# %%
import torch

a = torch.randn(1, 5)
print(a)
# Out:
# tensor([[ 0.7226,  0.2451, -1.7216,  0.4556,  0.6064]])

# %%
b = torch.tensor([[0, 1, 2, 3, 0, 0, 4],
                    [5, 4, 0, 0, 2, 5, 7]])

print(torch.nonzero(b))
# Out:
# tensor([[0, 1],
#         [0, 2],
#         [0, 3],
#         [0, 6],
#         [1, 0],
#         [1, 1],
#         [1, 4],
#         [1, 5],
#         [1, 6]])

# %%
a = torch.nonzero(b)[:, 0]
print(a)
# Out:
# tensor([0, 0, 0, 0, 1, 1, 1, 1, 1])

# %%
c = torch.nonzero(b)[:, 1]
print(c)
# Out:
# tensor([1, 2, 3, 6, 0, 1, 4, 5, 6])

# %%
import torch.nn

d = torch.randn(10, 10)
e = torch.randn(10, 10)

print((torch.matmul(d, e)).shape)
# Out:
# torch.Size([10, 10])

# %%
f = torch.matmul(d, e)
# print(f.view(-1, 1))

print((e.unsqueeze(0)).shape)
# Out:
# torch.Size([1, 10, 10])

# %%
print((e.squeeze(1)).shape)
# Out:
# torch.Size([10, 10])

# %%
g = torch.randint(0, 3, (3, 4))

# %%
print(torch.reshape(g, (-1,)))
# Out:
# tensor([0, 1, 0, 0, 0, 0, 2, 0, 2, 1, 1, 2])

# %%
ltp = torch.reshape(g, (-1,))
print(ltp)
# Out:
# tensor([0, 1, 0, 0, 0, 0, 2, 0, 2, 1, 1, 2])

# %%
print(g)
# Out:
# tensor([[0, 1, 0, 0],
#         [0, 0, 2, 0],
#         [2, 1, 1, 2]])
